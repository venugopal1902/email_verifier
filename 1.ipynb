# %%
import pandas as pd

# Load the text file
# sep=' ' for spaces, sep='\t' for tabs, sep='|' for pipes
df = pd.read_csv('C:\Users\venug\Downloads\data\data\bounce1.txt', sep=' ') 

# Save to CSV
df.to_csv('bounced1.csv', index=False)
